# %%
import pandas as pd
import numpy as np
import lxml.html as lh
import requests
from bs4 import BeautifulSoup

# %%
url='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
#Create a handle, page, to handle the contents of the website
page = requests.get(url)
#Store the contents of the website under doc
doc = lh.fromstring(page.content)
#Parse data that are stored between <tr>..</tr> of HTML
tr_elements = doc.xpath('//tr')

# %%
#Check the length of the first 12 rows
[len(T) for T in tr_elements[:12]]
# Out:
# [3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3]

# %%
(tr_elements)
# Out:
# [<Element tr at 0x7f896936f8b8>,
#  <Element tr at 0x7f896933f318>,
#  <Element tr at 0x7f896933f2c8>,
#  <Element tr at 0x7f896933f368>,
#  <Element tr at 0x7f8969323f98>,
#  <Element tr at 0x7f8969323f48>,
#  <Element tr at 0x7f8969323c28>,
#  <Element tr at 0x7f8969323728>,
#  <Element tr at 0x7f8969323ae8>,
#  <Element tr at 0x7f8969323818>,
#  <Element tr at 0x7f8969323908>,
#  <Element tr at 0x7f8969323958>,
#  <Element tr at 0x7f8969323868>,
#  <Element tr at 0x7f89693234a8>,
#  <Element tr at 0x7f8969344ef8>,
#  <Element tr at 0x7f8969344f98>,
#  <Element tr at 0x7f8969340048>,
#  <Element tr at 0x7f8969340098>,
#  <Element tr at 0x7f89693400e8>,
#  <Element tr at 0x7f8969340138>,
#  <Element tr at 0x7f8969340188>,
#  <Element tr at 0x7f89693401d8>,
#  <Element tr at 0x7f8969340228>,
#  <Element tr at 0x7f8969340278>,
#  <Element tr at 0x7f89693402c8>,
#  <Element tr at 0x7f8969340318>,
#  <Element tr at 0x7f8969340368>,
#  <Element tr at 0x7f89693403b8>,
#  <Element tr at 0x7f8969340408>,
#  <Element tr at 0x7f8969340458>,
#  <Element tr at 0x7f89693404a8>,
#  <Element tr at 0x7f89693404f8>,
#  <Element tr at 0x7f8969340548>,
#  <Element tr at 0x7f8969340598>,
#  <Element tr at 0x7f89693405e8>,
#  <Element tr at 0x7f8969340638>,
#  <Element tr at 0x7f8969340688>,
#  <Element tr at 0x7f89693406d8>,
#  <Element tr at 0x7f8969340728>,
#  <Element tr at 0x7f8969340778>,
#  <Element tr at 0x7f89693407c8>,
#  <Element tr at 0x7f8969340818>,
#  <Element tr at 0x7f8969340868>,
#  <Element tr at 0x7f89693408b8>,
#  <Element tr at 0x7f8969340908>,
#  <Element tr at 0x7f8969340958>,
#  <Element tr at 0x7f89693409a8>,
#  <Element tr at 0x7f89693409f8>,
#  <Element tr at 0x7f8969340a48>,
#  <Element tr at 0x7f8969340a98>,
#  <Element tr at 0x7f8969340ae8>,
#  <Element tr at 0x7f8969340b38>,
#  <Element tr at 0x7f8969340b88>,
#  <Element tr at 0x7f8969340bd8>,
#  <Element tr at 0x7f8969340c28>,
#  <Element tr at 0x7f8969340c78>,
#  <Element tr at 0x7f8969340cc8>,
#  <Element tr at 0x7f8969340d18>,
#  <Element tr at 0x7f8969340d68>,
#  <Element tr at 0x7f8969340db8>,
#  <Element tr at 0x7f8969340e08>,
#  <Element tr at 0x7f8969340e58>,
#  <Element tr at 0x7f8969340ea8>,
#  <Element tr at 0x7f8969340ef8>,
#  <Element tr at 0x7f8969340f48>,
#  <Element tr at 0x7f8969340f98>,
#  <Element tr at 0x7f8969345048>,
#  <Element tr at 0x7f8969345098>,
#  <Element tr at 0x7f89693450e8>,
#  <Element tr at 0x7f8969345138>,
#  <Element tr at 0x7f8969345188>,
#  <Element tr at 0x7f89693451d8>,
#  <Element tr at 0x7f8969345228>,
#  <Element tr at 0x7f8969345278>,
#  <Element tr at 0x7f89693452c8>,
#  <Element tr at 0x7f8969345318>,
#  <Element tr at 0x7f8969345368>,
#  <Element tr at 0x7f89693453b8>,
#  <Element tr at 0x7f8969345408>,
#  <Element tr at 0x7f8969345458>,
#  <Element tr at 0x7f89693454a8>,
#  <Element tr at 0x7f89693454f8>,
#  <Element tr at 0x7f8969345548>,
#  <Element tr at 0x7f8969345598>,
#  <Element tr at 0x7f89693455e8>,
#  <Element tr at 0x7f8969345638>,
#  <Element tr at 0x7f8969345688>,
#  <Element tr at 0x7f89693456d8>,
#  <Element tr at 0x7f8969345728>,
#  <Element tr at 0x7f8969345778>,
#  <Element tr at 0x7f89693457c8>,
#  <Element tr at 0x7f8969345818>,
#  <Element tr at 0x7f8969345868>,
#  <Element tr at 0x7f89693458b8>,
#  <Element tr at 0x7f8969345908>,
#  <Element tr at 0x7f8969345958>,
#  <Element tr at 0x7f89693459a8>,
#  <Element tr at 0x7f89693459f8>,
#  <Element tr at 0x7f8969345a48>,
#  <Element tr at 0x7f8969345a98>,
#  <Element tr at 0x7f8969345ae8>,
#  <Element tr at 0x7f8969345b38>,
#  <Element tr at 0x7f8969345b88>,
#  <Element tr at 0x7f8969345bd8>,
#  <Element tr at 0x7f8969345c28>,
#  <Element tr at 0x7f8969345c78>,
#  <Element tr at 0x7f8969345cc8>,
#  <Element tr at 0x7f8969345d18>,
#  <Element tr at 0x7f8969345d68>,
#  <Element tr at 0x7f8969345db8>,
#  <Element tr at 0x7f8969345e08>,
#  <Element tr at 0x7f8969345e58>,
#  <Element tr at 0x7f8969345ea8>,
#  <Element tr at 0x7f8969345ef8>,
#  <Element tr at 0x7f8969345f48>,
#  <Element tr at 0x7f8969345f98>,
#  <Element tr at 0x7f8969346048>,
#  <Element tr at 0x7f8969346098>,
#  <Element tr at 0x7f89693460e8>,
#  <Element tr at 0x7f8969346138>,
#  <Element tr at 0x7f8969346188>,
#  <Element tr at 0x7f89693461d8>,
#  <Element tr at 0x7f8969346228>,
#  <Element tr at 0x7f8969346278>,
#  <Element tr at 0x7f89693462c8>,
#  <Element tr at 0x7f8969346318>,
#  <Element tr at 0x7f8969346368>,
#  <Element tr at 0x7f89693463b8>,
#  <Element tr at 0x7f8969346408>,
#  <Element tr at 0x7f8969346458>,
#  <Element tr at 0x7f89693464a8>,
#  <Element tr at 0x7f89693464f8>,
#  <Element tr at 0x7f8969346548>,
#  <Element tr at 0x7f8969346598>,
#  <Element tr at 0x7f89693465e8>,
#  <Element tr at 0x7f8969346638>,
#  <Element tr at 0x7f8969346688>,
#  <Element tr at 0x7f89693466d8>,
#  <Element tr at 0x7f8969346728>,
#  <Element tr at 0x7f8969346778>,
#  <Element tr at 0x7f89693467c8>,
#  <Element tr at 0x7f8969346818>,
#  <Element tr at 0x7f8969346868>,
#  <Element tr at 0x7f89693468b8>,
#  <Element tr at 0x7f8969346908>,
#  <Element tr at 0x7f8969346958>,
#  <Element tr at 0x7f89693469a8>,
#  <Element tr at 0x7f89693469f8>,
#  <Element tr at 0x7f8969346a48>,
#  <Element tr at 0x7f8969346a98>,
#  <Element tr at 0x7f8969346ae8>,
#  <Element tr at 0x7f8969346b38>,
#  <Element tr at 0x7f8969346b88>,
#  <Element tr at 0x7f8969346bd8>,
#  <Element tr at 0x7f8969346c28>,
#  <Element tr at 0x7f8969346c78>,
#  <Element tr at 0x7f8969346cc8>,
#  <Element tr at 0x7f8969346d18>,
#  <Element tr at 0x7f8969346d68>,
#  <Element tr at 0x7f8969346db8>,
#  <Element tr at 0x7f8969346e08>,
#  <Element tr at 0x7f8969346e58>,
#  <Element tr at 0x7f8969346ea8>,
#  <Element tr at 0x7f8969346ef8>,
#  <Element tr at 0x7f8969346f48>,
#  <Element tr at 0x7f8969346f98>,
#  <Element tr at 0x7f8969347048>,
#  <Element tr at 0x7f8969347098>,
#  <Element tr at 0x7f89693470e8>,
#  <Element tr at 0x7f8969347138>,
#  <Element tr at 0x7f8969347188>,
#  <Element tr at 0x7f89693471d8>,
#  <Element tr at 0x7f8969347228>,
#  <Element tr at 0x7f8969347278>,
#  <Element tr at 0x7f89693472c8>,
#  <Element tr at 0x7f8969347318>,
#  <Element tr at 0x7f8969347368>,
#  <Element tr at 0x7f89693473b8>,
#  <Element tr at 0x7f8969347408>,
#  <Element tr at 0x7f8969347458>,
#  <Element tr at 0x7f89693474a8>,
#  <Element tr at 0x7f89693474f8>,
#  <Element tr at 0x7f8969347548>,
#  <Element tr at 0x7f8969347598>,
#  <Element tr at 0x7f89693475e8>,
#  <Element tr at 0x7f8969347638>,
#  <Element tr at 0x7f8969347688>,
#  <Element tr at 0x7f89693476d8>,
#  <Element tr at 0x7f8969347728>,
#  <Element tr at 0x7f8969347778>,
#  <Element tr at 0x7f89693477c8>,
#  <Element tr at 0x7f8969347818>,
#  <Element tr at 0x7f8969347868>,
#  <Element tr at 0x7f89693478b8>,
#  <Element tr at 0x7f8969347908>,
#  <Element tr at 0x7f8969347958>,
#  <Element tr at 0x7f89693479a8>,
#  <Element tr at 0x7f89693479f8>,
#  <Element tr at 0x7f8969347a48>,
#  <Element tr at 0x7f8969347a98>,
#  <Element tr at 0x7f8969347ae8>,
#  <Element tr at 0x7f8969347b38>,
#  <Element tr at 0x7f8969347b88>,
#  <Element tr at 0x7f8969347bd8>,
#  <Element tr at 0x7f8969347c28>,
#  <Element tr at 0x7f8969347c78>,
#  <Element tr at 0x7f8969347cc8>,
#  <Element tr at 0x7f8969347d18>,
#  <Element tr at 0x7f8969347d68>,
#  <Element tr at 0x7f8969347db8>,
#  <Element tr at 0x7f8969347e08>,
#  <Element tr at 0x7f8969347e58>,
#  <Element tr at 0x7f8969347ea8>,
#  <Element tr at 0x7f8969347ef8>,
#  <Element tr at 0x7f8969347f48>,
#  <Element tr at 0x7f8969347f98>,
#  <Element tr at 0x7f8969348048>,
#  <Element tr at 0x7f8969348098>,
#  <Element tr at 0x7f89693480e8>,
#  <Element tr at 0x7f8969348138>,
#  <Element tr at 0x7f8969348188>,
#  <Element tr at 0x7f89693481d8>,
#  <Element tr at 0x7f8969348228>,
#  <Element tr at 0x7f8969348278>,
#  <Element tr at 0x7f89693482c8>,
#  <Element tr at 0x7f8969348318>,
#  <Element tr at 0x7f8969348368>,
#  <Element tr at 0x7f89693483b8>,
#  <Element tr at 0x7f8969348408>,
#  <Element tr at 0x7f8969348458>,
#  <Element tr at 0x7f89693484a8>,
#  <Element tr at 0x7f89693484f8>,
#  <Element tr at 0x7f8969348548>,
#  <Element tr at 0x7f8969348598>,
#  <Element tr at 0x7f89693485e8>,
#  <Element tr at 0x7f8969348638>,
#  <Element tr at 0x7f8969348688>,
#  <Element tr at 0x7f89693486d8>,
#  <Element tr at 0x7f8969348728>,
#  <Element tr at 0x7f8969348778>,
#  <Element tr at 0x7f89693487c8>,
#  <Element tr at 0x7f8969348818>,
#  <Element tr at 0x7f8969348868>,
#  <Element tr at 0x7f89693488b8>,
#  <Element tr at 0x7f8969348908>,
#  <Element tr at 0x7f8969348958>,
#  <Element tr at 0x7f89693489a8>,
#  <Element tr at 0x7f89693489f8>,
#  <Element tr at 0x7f8969348a48>,
#  <Element tr at 0x7f8969348a98>,
#  <Element tr at 0x7f8969348ae8>,
#  <Element tr at 0x7f8969348b38>,
#  <Element tr at 0x7f8969348b88>,
#  <Element tr at 0x7f8969348bd8>,
#  <Element tr at 0x7f8969348c28>,
#  <Element tr at 0x7f8969348c78>,
#  <Element tr at 0x7f8969348cc8>,
#  <Element tr at 0x7f8969348d18>,
#  <Element tr at 0x7f8969348d68>,
#  <Element tr at 0x7f8969348db8>,
#  <Element tr at 0x7f8969348e08>,
#  <Element tr at 0x7f8969348e58>,
#  <Element tr at 0x7f8969348ea8>,
#  <Element tr at 0x7f8969348ef8>,
#  <Element tr at 0x7f8969348f48>,
#  <Element tr at 0x7f8969348f98>,
#  <Element tr at 0x7f8969349048>,
#  <Element tr at 0x7f8969349098>,
#  <Element tr at 0x7f89693490e8>,
#  <Element tr at 0x7f8969349138>,
#  <Element tr at 0x7f8969349188>,
#  <Element tr at 0x7f89693491d8>,
#  <Element tr at 0x7f8969349228>,
#  <Element tr at 0x7f8969349278>,
#  <Element tr at 0x7f89693492c8>,
#  <Element tr at 0x7f8969349318>,
#  <Element tr at 0x7f8969349368>,
#  <Element tr at 0x7f89693493b8>,
#  <Element tr at 0x7f8969349408>,
#  <Element tr at 0x7f8969349458>,
#  <Element tr at 0x7f89693494a8>,
#  <Element tr at 0x7f89693494f8>,
#  <Element tr at 0x7f8969349548>,
#  <Element tr at 0x7f8969349598>,
#  <Element tr at 0x7f89693495e8>,
#  <Element tr at 0x7f8969349638>,
#  <Element tr at 0x7f8969349688>,
#  <Element tr at 0x7f89693496d8>,
#  <Element tr at 0x7f8969349728>,
#  <Element tr at 0x7f8969349778>,
#  <Element tr at 0x7f89693497c8>,
#  <Element tr at 0x7f8969349818>,
#  <Element tr at 0x7f8969349868>,
#  <Element tr at 0x7f89693498b8>]

# %%
#Create empty list
col=[]
i=0
#For each row, store each first element (header) and an empty list
for t in tr_elements[0]:
    i+=1
    name=t.text_content()
    col.append((name,[]))

# %%
col
# Out:
# [('Postcode', []), ('Borough', []), ('Neighbourhood\n', [])]

# %%
#Since out first row is the header, data is stored on the second row onwards
for j in range(1,len(tr_elements)):
    #T is our j'th row
    T=tr_elements[j]
    
    #If row is not of size 10, the //tr data is not from our table 
    if len(T)!=3:
        break
    
    #i is the index of our column
    i=0
    
    #Iterate through each element of the row
    for t in T.iterchildren():
        data=t.text_content() 
        #Check if row is empty
        if i>0:
        #Convert any numerical value to integers
            try:
                data=int(data)
            except:
                pass
        #Append the data to the empty list of the i'th column
        col[i][1].append(data)
        #Increment i for the next column
        i+=1

# %%
[len(C) for (title,C) in col]
# Out:
# [288, 288, 288]

# %%
Dict={title:column for (title,column) in col}
df=pd.DataFrame(Dict)
df.head()
# Out:
#             Borough     Neighbourhood\n Postcode
# 0      Not assigned      Not assigned\n      M1A
# 1      Not assigned      Not assigned\n      M2A
# 2        North York         Parkwoods\n      M3A
# 3        North York  Victoria Village\n      M4A
# 4  Downtown Toronto      Harbourfront\n      M5A

# %%
df =df[df['Borough']!='Not assigned']

# %%
df.astype('str')
df['Neighbourhood\n'] = df['Neighbourhood\n'].str[:-1]
df.columns=['borough', 'neighbourhood','postalcode']
df.head()
# Out:
#             borough     neighbourhood postalcode
# 2        North York         Parkwoods        M3A
# 3        North York  Victoria Village        M4A
# 4  Downtown Toronto      Harbourfront        M5A
# 5  Downtown Toronto       Regent Park        M5A
# 6        North York  Lawrence Heights        M6A

# %%
df.columns=['borough', 'neighbourhood','postalcode']

# %%
df
# Out:
#               borough                                      neighbourhood  \
# 2          North York                                          Parkwoods
# 3          North York                                   Victoria Village
# 4    Downtown Toronto                                       Harbourfront
# 6          North York                                   Lawrence Heights
# 8        Queen's Park                                       Not assigned
# 10          Etobicoke                                   Islington Avenue
# 11        Scarborough                                              Rouge
# 14         North York                                    Don Mills North
# 15          East York                                   Woodbine Gardens
# 17   Downtown Toronto                                            Ryerson
# 19         North York                                          Glencairn
# 22          Etobicoke                                         Cloverdale
# 27        Scarborough                                     Highland Creek
# 31         North York                                    Flemingdon Park
# 33          East York                                   Woodbine Heights
# 34   Downtown Toronto                                     St. James Town
# 35               York                                 Humewood-Cedarvale
# 38          Etobicoke                                  Bloordale Gardens
# 42        Scarborough                                          Guildwood
# 47       East Toronto                                        The Beaches
# 48   Downtown Toronto                                        Berczy Park
# 49               York                                Caledonia-Fairbanks
# 53        Scarborough                                             Woburn
# 56          East York                                            Leaside
# 57   Downtown Toronto                                 Central Bay Street
# 58   Downtown Toronto                                           Christie
# 62        Scarborough                                          Cedarbrae
# 63         North York                                  Hillcrest Village
# 64         North York                                     Bathurst Manor
# 67          East York                                   Thorncliffe Park
# ..                ...                                                ...
# 168   Central Toronto                                 North Toronto West
# 169   Central Toronto                                          The Annex
# 172      West Toronto                                           Parkdale
# 174       Mississauga              Canada Post Gateway Processing Centre
# 176         Etobicoke                                  Kingsview Village
# 180       Scarborough                                          Agincourt
# 183   Central Toronto                                         Davisville
# 184  Downtown Toronto                                            Harbord
# 186      West Toronto                                          Runnymede
# 191       Scarborough                                     Clarks Corners
# 196   Central Toronto                                         Moore Park
# 198  Downtown Toronto                                          Chinatown
# 205       Scarborough                                    Agincourt North
# 211   Central Toronto                                          Deer Park
# 216  Downtown Toronto                                           CN Tower
# 225         Etobicoke                                  Humber Bay Shores
# 228         Etobicoke                                     Albion Gardens
# 236       Scarborough                                    L'Amoreaux West
# 239  Downtown Toronto                                           Rosedale
# 240  Downtown Toronto                    Stn A PO Boxes 25 The Esplanade
# 243         Etobicoke                                          Alderwood
# 245         Etobicoke                                          Northwest
# 246       Scarborough                                        Upper Rouge
# 249  Downtown Toronto                                        Cabbagetown
# 251  Downtown Toronto                               First Canadian Place
# 255         Etobicoke                                       The Kingsway
# 262  Downtown Toronto                               Church and Wellesley
# 265      East Toronto  Business Reply Mail Processing Centre 969 Eastern
# 266         Etobicoke                                         Humber Bay
# 282         Etobicoke                           Kingsway Park South West
#
#     postalcode
# 2          M3A
# 3          M4A
# 4          M5A
# 6          M6A
# 8          M7A
# 10         M9A
# 11         M1B
# 14         M3B
# 15         M4B
# 17         M5B
# 19         M6B
# 22         M9B
# 27         M1C
# 31         M3C
# 33         M4C
# 34         M5C
# 35         M6C
# 38         M9C
# 42         M1E
# 47         M4E
# 48         M5E
# 49         M6E
# 53         M1G
# 56         M4G
# 57         M5G
# 58         M6G
# 62         M1H
# 63         M2H
# 64         M3H
# 67         M4H
# ..         ...
# 168        M4R
# 169        M5R
# 172        M6R
# 174        M7R
# 176        M9R
# 180        M1S
# 183        M4S
# 184        M5S
# 186        M6S
# 191        M1T
# 196        M4T
# 198        M5T
# 205        M1V
# 211        M4V
# 216        M5V
# 225        M8V
# 228        M9V
# 236        M1W
# 239        M4W
# 240        M5W
# 243        M8W
# 245        M9W
# 246        M1X
# 249        M4X
# 251        M5X
# 255        M8X
# 262        M4Y
# 265        M7Y
# 266        M8Y
# 282        M8Z
#
# [103 rows x 3 columns]
